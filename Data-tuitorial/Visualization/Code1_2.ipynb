# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading Data

# %%
with open("Data/Goals.txt","r") as goalData:
    homeTeamLine = goalData.readline()
    homeTeamLine = homeTeamLine.strip(" \n")
    homeTeamLine = homeTeamLine.split(" ")

    HomeTeamGoals = [int(x) for x in homeTeamLine]
    
    awayTeamLine = goalData.readline()
    awayTeamLine = awayTeamLine.strip(" \n")
    awayTeamLine = awayTeamLine.split(" ")

    AwayTeamGoals = [int(x) for x in awayTeamLine]

# %% [markdown]
# # Histogram

# %%
x=[]
for i in range(1,len(HomeTeamGoals)+1):
    x.append(i)

# %%
fig2 = plt.figure("Second",figsize = (6,6))
ax1 = fig2.add_subplot(1,1,1)

ax1.hist(x = HomeTeamGoals, 
         bins = 7, #int / sequence 
         align = "mid", # left, mid, right
         #range = (1,3), # (min,max)
         color = "red",
         cumulative= False # True, False
)

plt.show()

# %%
fig2 = plt.figure("Second",figsize = (6,6))
ax1 = fig2.add_subplot(1,1,1)

ax1.hist(x = (HomeTeamGoals, AwayTeamGoals), 
         bins = 7, #int / sequence 
         align = "mid", # left, mid, right
         #range = (1,3), # (min,max)
         color = ("red","blue"),
         cumulative= False # True, False
)

plt.show()

# %%
fig2 = plt.figure("Second",figsize = (6,6))
ax1 = fig2.add_subplot(1,1,1)

N, bins, patches = ax1.hist(x = (HomeTeamGoals, AwayTeamGoals), 
         bins = 7, #int / sequence 
         align = "mid", # left, mid, right
         #range = (1,3), # (min,max)
         color = ("red","blue"),
         cumulative= False # True, False
)

patches[1][2].set_facecolor("green")
patches[0][3].set_width(0.5)

plt.show()

# %%
bins
# Out:
# array([0.        , 0.85714286, 1.71428571, 2.57142857, 3.42857143,
#        4.28571429, 5.14285714, 6.        ])

# %%
from matplotlib.patches import Rectangle

# %%
redRectangle = Rectangle((0,0),1,1,color = "red") #(x,y), width, height, facecolor
blueRectangle = Rectangle((0,0),1,1,color = "blue") #(x,y), width, height, facecolor

# %%
labels = ["Home Team Goals","Away Team Goals"]
Boxes = [redRectangle,blueRectangle]

plt.legend(Boxes,labels)

# %% [markdown]
# # Bar Graph

# %%
avgGoalsScoredHome = sum(HomeTeamGoals)/len(HomeTeamGoals)
avgGoalsScoredAway = sum(AwayTeamGoals)/len(AwayTeamGoals)

# %%
fig2 = plt.figure("Second",figsize = (6,6))
ax1 = fig2.add_subplot(1,1,1)

ax1.bar( x = [1,2],
        height= (avgGoalsScoredHome,avgGoalsScoredAway),
        width= 0.35,
        align= "center",
        color = ["red","blue"],
        bottom = [0,0],
        )

plt.xticks([1,2],["Home Team","Away Team"])

ax1.set_ylim(0,2)
ax1.set_xlim(0.5,2.5)


plt.show()

# %%
fig2 = plt.figure("Second",figsize = (6,6))
ax1 = fig2.add_subplot(1,1,1)

ax1.bar( x = [1,1],
        height= (avgGoalsScoredHome,avgGoalsScoredAway),
        width= 0.15,
        align= "center",
        color = ["red","blue"],
        bottom = [0,avgGoalsScoredHome],
        xerr = 0.15,
        #xerr = [0.15,0.4],
        #xerr = [[0.15,0.4],[0.4,0.15]],
        yerr = 0.15,
        #yerr = [0.15,0.4],
        #yerr = [[0.15,0.4],[0.4,0.15]],
        ecolor = "orange",
        )

plt.xticks([1,2],["Home Team","Away Team"])

ax1.set_ylim(0,4)
ax1.set_xlim(0.5,2.5)


plt.show()

# %%
fig3 = plt.figure("Third", figsize = (6,6))
ax1 = fig3.add_subplot(1,1,1)

ax1.boxplot(x = [HomeTeamGoals,AwayTeamGoals],
          #  positions= [1,5],
          sym = "^", #"o", "s", "d", "v", "^", "<", ">", "p", "h", "+", "x", "D", "|", "_"
          whis  = [10,90],
          #widths = 0.5
          notch= True,
          conf_intervals = [[0.9,1.1],[0.2,1.9]],
)

ax1.set_ylim(0,7)
plt.show()

# %% [markdown]
# # Pie Charts

# %%
totalHomeGoalsScored = sum(HomeTeamGoals)
totalAwayGoalsScored = sum(AwayTeamGoals)

fig2 = plt.figure("Second",figsize = (6,6))
ax1 = fig2.add_subplot(1,1,1)

ax1.pie(x = [totalHomeGoalsScored,totalAwayGoalsScored],
        labels = ["Home Team","Away Team"],
        labeldistance=0.5,
        colors= ["red","green"],
        explode= [0,0.1],
        shadow= True,
        #radius= 1,
        #center= [0,0],
        )

plt.show()

# %% [markdown]
# # 2 Dimensional Histogram

# %%
fig2 = plt.figure("Second",figsize = (6,6))
ax1 = fig2.add_subplot(1,1,1)

plt.hist2d(x = HomeTeamGoals,
           y = AwayTeamGoals,
           bins= [range(8),range(7)]
           )#[xbins,ybins]

plt.colorbar()

plt.show()

# %% [markdown]
# # Images

# %%
import matplotlib.image as mpimg

# %%
fig = plt.figure("First",figsize = (6,6))
ax1 = fig.add_subplot(1,1,1)

img = mpimg.imread("Images/target.png")
ax1.imshow(img,)

plt.show()

# %% [markdown]
# # Colour Maps

# %%
fig2 = plt.figure("Second",figsize = (6,6))
ax1 = fig2.add_subplot(1,1,1)

#plt.hist2d(x = HomeTeamGoals,
#           y = AwayTeamGoals,
#           bins= [range(8),range(7)], #[xbins,ybins]
#           cmap = plt.cm.ocean, #plt.cm.hot, plt.cm.cool, plt.cm.Blues, plt.cm.Greens, plt.cm.Reds, (_r for reverse)
#           )
#plt.colorbar()

cmap = plt.cm.get_cmap("jet",8) #3 - > only 3 colours
colors = cmap(range(8)) #6
n,bins,patches = ax1.hist(HomeTeamGoals,bins = range(8),edgecolor = "black")

for color,patch in zip(colors,patches):
    patch.set_facecolor(color)

plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9656\2463936422.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap("jet",8) #3 - > only 3 colours

# %%
fig2 = plt.figure("Second",figsize = (6,6))
ax1 = fig2.add_subplot(1,1,1)

counts,xedges,yedges,Image = ax1.hist2d(x = HomeTeamGoals,
           y = AwayTeamGoals,
           bins= [range(8),range(7)], #[xbins,ybins]
           cmap = plt.cm.jet
           )

extent = [xedges[0],xedges[-1],yedges[-1],yedges[0]]

im = ax1.imshow(counts,extent=extent)

fig2.colorbar(im,ax=ax1)
#plt.colorbar()

plt.show()

# %% [markdown]
# # 3D line and Scatter plots

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig2 = plt.figure("Second",figsize = (6,10))
ax1 = fig2.add_subplot(2,1,1,projection = "3d")
ax2 = fig2.add_subplot(2,1,2,projection = "3d")

ax1.plot(xs = x,ys = HomeTeamGoals,zs = AwayTeamGoals)

ax1.set_xlabel("Game Number")
ax1.set_ylabel("Home Team Goals")
ax1.set_zlabel("Away Team Goals")
ax1.set_title("3D line Plot")

ax2.scatter(xs = x,ys = HomeTeamGoals,zs = AwayTeamGoals,
            depthshade = True)


ax2.view_init(00,10) #ElevationAngle, RotationAngle

for angle in range(0,360):
    ax2.view_init(30,angle)
    plt.draw()
    plt.pause(0.01)

#plt.show()

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading Data

# %%
with open("Data/Goals.txt","r") as goalData:
    homeTeamLine = goalData.readline()
    homeTeamLine = homeTeamLine.strip(" \n")
    homeTeamLine = homeTeamLine.split(" ")

    HomeTeamGoals = [int(x) for x in homeTeamLine]
    
    awayTeamLine = goalData.readline()
    awayTeamLine = awayTeamLine.strip(" \n")
    awayTeamLine = awayTeamLine.split(" ")

    AwayTeamGoals = [int(x) for x in awayTeamLine]

# %% [markdown]
# # Scatter Plot

# %%
plt.scatter(x=HomeTeamGoals,y=AwayTeamGoals)
plt.show()

# %%
plt.scatter(HomeTeamGoals,AwayTeamGoals,s=80)
plt.show()

# %%
plt.scatter(HomeTeamGoals,AwayTeamGoals,s=50,c="#3D234F")
plt.show()

# %%
plt.scatter(HomeTeamGoals,AwayTeamGoals,s=50,c=[[1,0,0.4,0.9]])
plt.show()

# %%
import math

# %%
def distFromZero(htg,atg):
    return math.sqrt(htg**2+atg**2)

# %%
colors=[]
for i in range(len(HomeTeamGoals)):
    colors.append(distFromZero(HomeTeamGoals[i],AwayTeamGoals[i]))

# %%
plt.scatter(HomeTeamGoals,
            AwayTeamGoals,
            s=50,
            c=colors,
            marker="*",
            alpha=0.8)
plt.show()

# %%
fig = plt.figure(figsize=(10,10),facecolor="Blue")
plt.scatter(HomeTeamGoals,AwayTeamGoals)
plt.show()

# %%
fig = plt.figure(1,figsize=(10,10),facecolor="Blue")
fig2 = plt.figure(2,figsize=(10,6),facecolor="red")
plt.figure(1)
plt.scatter(HomeTeamGoals,AwayTeamGoals)
plt.show()

# %%
fig = plt.figure(1,figsize=(10,10),facecolor="Blue")
fig2 = plt.figure(2,figsize=(10,6),facecolor="red")
plt.figure(2)
plt.scatter(HomeTeamGoals,AwayTeamGoals)
plt.show()

# %%
fig = plt.figure(1,figsize=(10,10))
ax1=fig.add_subplot(3,3,1)
ax2=fig.add_subplot(3,3,2)
plt.scatter(HomeTeamGoals,AwayTeamGoals)
plt.show()

# %%
fig = plt.figure(1,figsize=(10,10))
axList = []
for i in range(1,10):
    axList.append(fig.add_subplot(3,3,i))
plt.scatter(HomeTeamGoals,AwayTeamGoals)
plt.show()

# %%
fig = plt.figure(1,figsize=(10,10))
axList = []
for i in range(1,10):
    axList.append(fig.add_subplot(3,3,i))
    plt.scatter(HomeTeamGoals,AwayTeamGoals)
plt.show()

# %%
fig = plt.figure(1,figsize=(10,10))
axList = []
for i in range(1,10):
    axList.append(fig.add_subplot(3,3,i))
axList[5].scatter(HomeTeamGoals,AwayTeamGoals)
axList[2].scatter(AwayTeamGoals,HomeTeamGoals,c="red")
plt.sca(axList[3])
plt.scatter(HomeTeamGoals,AwayTeamGoals,c="green")
plt.show()

# %% [markdown]
# # Line Plot

# %%
x=[]
for i in range(1,len(HomeTeamGoals)+1):
    x.append(i)

fig3 = plt.figure(1,figsize=(10,5))
ax1 = fig3.add_subplot(1,1,1)
plt.plot(x,HomeTeamGoals)
plt.show()

# %%
fig3 = plt.figure(1,figsize=(10,5))
ax1 = fig3.add_subplot(1,1,1)
plt.plot(x,HomeTeamGoals,color = "red",marker = "o") # marker = o,+,*,^,|
plt.show()

# %%
fig3 = plt.figure(1,figsize=(10,5))
ax1 = fig3.add_subplot(1,1,1)
plt.plot(x,HomeTeamGoals,color = "red",marker = "o",markerfacecolor="blue")
plt.show()

# %%
fig3 = plt.figure(1,figsize=(10,5))
ax1 = fig3.add_subplot(1,1,1)
plt.plot(x,HomeTeamGoals,color = "red",marker = "o",markerfacecolor="blue",markersize=10)
plt.show()

# %%
fig3 = plt.figure(1,figsize=(10,5))
ax1 = fig3.add_subplot(1,1,1)
plt.plot(x,HomeTeamGoals,color = "red",marker = "o",linestyle="--")
plt.show()

# %%
fig3 = plt.figure(1,figsize=(15,5))
ax1 = fig3.add_subplot(1,1,1)
ax1.plot(x,HomeTeamGoals,color = "red",marker = "o",linestyle="--")
ax1.plot(x,AwayTeamGoals,color = "green",linestyle="-")
plt.show()

# %%
fig3 = plt.figure(1,figsize=(15,5))
ax1 = fig3.add_subplot(1,1,1)
ax1.plot(x,HomeTeamGoals,color = "red",marker = "o",linestyle="--")
ax1.scatter(x,AwayTeamGoals,color = "green")
plt.show()

# %% [markdown]
# # Reading a TXT File

# %%
def readTxt():
    f = open("Data/Sheet1E1.txt","r")
    data = {}
        
    for line in f:
        part1 = line.strip("\n").split(" ")
        dataName = part1[0]
        restData = part1[1:]

        finalData = []
        for x in restData:
            finalData.append(int(x))
        data[dataName] = finalData
            
    f.close()
    
    return data

# %% [markdown]
# # Reading a CSV File

# %%
def readCSV():
    f = open("Data/Sheet1E1.csv","r")  
    data = {}
    
    firstLine = f.readline().strip("\n").split(",")[1:]

    for name in firstLine:
        data[name] = []    
    
    for line in f:
        processedLine = line.strip("\n").split(",")[1:]
        
        for index in range(len(processedLine)):
            name = firstLine[index]
            dataPoint = int(processedLine[index])
            data[name].append(dataPoint)
        
    return data

# %%
data = readCSV()
HPAB=[]
print(data.keys())
# Out:
# dict_keys(['Games', 'AtBase', 'Hits'])

# %% [markdown]
# # Exercise 1

# %%
for i in range(len(data["Hits"])):
    if data["AtBase"][i] == 0:
        HPAB.append(0)
    else:
        HPAB.append(data["Hits"][i]/data["AtBase"][i])

# %%
fig = plt.figure("HPABY",figsize=(8,8))

ax =fig.add_subplot(1,1,1)

ax.scatter(data["Games"],HPAB,s=5,c="green")

plt.show()

# %% [markdown]
# # Exercise 2

# %%
def readCSV2():
    f = open("Data/Sheet1E2.csv","r")  
    data = {}
    
    firstLine = f.readline().strip("\n").split(",")[1:]

    for name in firstLine:
        data[name] = []    
    
    for line in f:
        processedLine = line.strip("\n").split(",")[1:]
        
        for index in range(len(processedLine)):
            name = firstLine[index]
            dataPoint = int(processedLine[index])
            data[name].append(dataPoint)
        
    return data

# %%
data = readCSV2()
print(data.keys())
# Out:
# dict_keys(['Year', 'AtBase', 'Hits'])

# %%
HPAB=[]
for i in range(len(data["Hits"])):
    if data["AtBase"][i] == 0:
        HPAB.append(0)
    else:
        HPAB.append(data["Hits"][i]/data["AtBase"][i])

# %%
fig = plt.figure("HPABY",figsize=(10,10))

ax = fig.add_subplot(2,1,1)

ax.plot(data["Year"],HPAB,c="green")

ax2 = fig.add_subplot(2,1,2)

ax2.plot(data["Year"],data["AtBase"],c="purple")

plt.show()

# %% [markdown]
# # Editing the axis

# %%
fig4 = plt.figure("Second",figsize=(10,10))
ax1 = fig4.add_subplot(2,1,1)
ax2 = fig4.add_subplot(2,1,2)
ax1.plot(x,HomeTeamGoals,c="red")
ax1.set_xlim(145,-1) #(left = ,right = ) or ( , )
ax1.set_ylim(0,7) #lower , upper
ax1.set_title("Home Team Goals over the season", 
            loc = "center", 
            fontdict = {"fontsize":20,
                        "color":"blue"})
ax1.set_xlabel("Game number",labelpad=2)
ax1.set_ylabel("Home team Goals")


ax2.plot(x,AwayTeamGoals)
ax2.set_xlim(0,150)
ax2.set_title("Away Team Goals over the season",
                loc = "center",
                fontdict = {"fontsize":20})
ax2.set_xlabel("Game number", labelpad = 2,
                fontdict = {"rotation":30} )
ax2.set_ylabel("Away Team Goals")
plt.show()

# %%
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

x=[]
for i in range(1,len(HomeTeamGoals)+1):
    x.append(i)

majorTickLocation = MultipleLocator(10)
minorTickLocation = MultipleLocator(1)

majorTickFormat = FormatStrFormatter("%03d")
yMajorTickFormat = FormatStrFormatter("%02d")

fig4 = plt.figure("Second",figsize=(10,10))
ax1 = fig4.add_subplot(2,1,1)

ax1.plot(x,HomeTeamGoals,c="red")
ax1.set_xlim(0,145) 
ax1.set_ylim(0,7) 
ax1.set_title("Home Team Goals over the season", 
            loc = "center", 
            fontdict = {"fontsize":20,
                        "color":"blue"})
ax1.set_xlabel("Game number",labelpad=2)
ax1.set_ylabel("Home team Goals")
ax1.xaxis.set_major_locator(majorTickLocation)
ax1.xaxis.set_minor_locator(minorTickLocation)
ax1.xaxis.set_major_formatter(majorTickFormat)
ax1.yaxis.set_major_formatter(yMajorTickFormat)

plt.show()

# %%
majorTickLocation = MultipleLocator(10)
minorTickLocation = MultipleLocator(1)

majorTickFormat = FormatStrFormatter("%03d")
yMajorTickFormat = FormatStrFormatter("%02d")

fig4 = plt.figure("Second",figsize=(10,10))
ax1 = fig4.add_subplot(2,1,1)

ax1.plot(x,HomeTeamGoals,c="red")
ax1.set_xlim(0,145) 
ax1.set_ylim(0,7) 
ax1.set_title("Home Team Goals over the season", 
            loc = "center", 
            fontdict = {"fontsize":20,
                        "color":"blue"})
ax1.set_xlabel("Game number",labelpad=2)
ax1.set_ylabel("Home team Goals")
ax1.xaxis.set_major_locator(majorTickLocation)
ax1.xaxis.set_minor_locator(minorTickLocation)

#xTickLabels = ax1.get_xticks().tolist()

#xTickLabels = [int(t) for t in ax1.get_xticks().tolist()]

#xTickLabels[2]="Ten"
#xTickLabels[3]=20

#ax1.set_xticklabels(xTickLabels)

#ax1.set_xticklabels(["Test1","Start","","","Test3"])

#plt.sca(ax1)
#plt.xticks([10,120,140],["One","Two","Three"])

i=0
for xticks in ax1.get_xmajorticklabels():
    #xticks.set_rotation(45)
    xticks.set_rotation(i)
    i+=2



plt.show()

# %% [markdown]
# # Exercise 3

# %%
min(data["Year"])
# Out:
# 1884

# %%
majorLocator = MultipleLocator(10)
minorLocator = MultipleLocator(2)

fig = plt.figure("HPABY",figsize=(10,10))
ax = fig.add_subplot(2,1,1)
ax.plot(data["Year"],HPAB,c="green")
ax2 = fig.add_subplot(2,1,2)
ax2.plot(data["Year"],data["AtBase"],c="purple")

ax.set_ylim(-0.01,1)
ax.set_xlim(data["Year"][0]-1,data["Year"][-1]+1)
ax.set_xlabel("Year")
ax.set_ylabel("HPAB")
ax.set_title("HPAB for each Year for player 1")
ax.xaxis.set_major_locator(majorLocator)
ax.xaxis.set_minor_locator(minorLocator)

ax2.set_ylim(-5,600)
ax2.set_xlim(data["Year"][0]-1,data["Year"][-1]+1)
ax2.set_xlabel("Year")
ax2.set_ylabel("At Base Count")
ax2.set_title("At Base Count for each Year for player 1")
ax2.xaxis.set_major_locator(majorLocator)
ax2.xaxis.set_minor_locator(minorLocator)

plt.show()

# %%
majorLocator = MultipleLocator(10)
minorLocator = MultipleLocator(2)

fig = plt.figure("HPABY",figsize=(10,10))
ax = fig.add_subplot(2,1,1)
ax.plot(data["Year"],HPAB,c="green",label = "Line")
ax2 = fig.add_subplot(2,1,2)
ax2.plot(data["Year"],data["AtBase"],c="purple",label = "Line2")

ax.set_ylim(-0.01,1)
ax.set_xlim(data["Year"][0]-1,data["Year"][-1]+1)
ax.set_xlabel("Year")
ax.set_ylabel("HPAB")
ax.set_title("HPAB for each Year for player 1")
ax.xaxis.set_major_locator(majorLocator)
ax.xaxis.set_minor_locator(minorLocator)
ax.legend()

ax2.set_ylim(-5,600)
ax2.set_xlim(data["Year"][0]-1,data["Year"][-1]+1)
ax2.set_xlabel("Year")
ax2.set_ylabel("At Base Count")
ax2.set_title("At Base Count for each Year for player 1")
ax2.xaxis.set_major_locator(majorLocator)
ax2.xaxis.set_minor_locator(minorLocator)
ax2.legend(loc = "upper center") # "upper center" , "lower center" , "center right" , "center left"

majorLabels =[]
for tempValue in ax.get_xticks().tolist():
    intValue = int(tempValue)
    strValue = str(intValue)

plt.show()

# %%
with open("Data/Goals.txt","r") as goalData:
    homeTeamLine = goalData.readline()
    homeTeamLine = homeTeamLine.strip(" \n")
    homeTeamLine = homeTeamLine.split(" ")

    HomeTeamGoals = [int(x) for x in homeTeamLine]
    awayTeamLine = goalData.readline()
    awayTeamLine = awayTeamLine.strip(" \n")
    awayTeamLine = awayTeamLine.split(" ")

    AwayTeamGoals = [int(x) for x in awayTeamLine]

x=[]
for i in range(1,len(HomeTeamGoals)+1):
    x.append(i)

fig2 = plt.figure("Second",figsize=(8,8))


ax1 = fig2.add_subplot(2,1,1)
ax2 = fig2.add_subplot(2,1,2)

ax1.plot(x,HomeTeamGoals,color =(1,0,.5), linestyle="--", linewidth=1, label = "HTG")
ax1.plot(x,AwayTeamGoals,color ="blue", linestyle=":", linewidth=1, label = "ATG")


ax1.set_xlim(0,145)
ax1.set_ylim(0,7)
ax1.set_title("Home Team Goals over the season")
ax1.set_xlabel("Game number", labelpad=1)
ax1.set_ylabel("Home Team Goals")
ax1.legend(loc = "best") # upper, lower, center, left, right, best


plt.show()

# %%
with open("Data/Goals.txt","r") as goalData:
    homeTeamLine = goalData.readline()
    homeTeamLine = homeTeamLine.strip(" \n")
    homeTeamLine = homeTeamLine.split(" ")

    HomeTeamGoals = [int(x) for x in homeTeamLine]
    awayTeamLine = goalData.readline()
    awayTeamLine = awayTeamLine.strip(" \n")
    awayTeamLine = awayTeamLine.split(" ")

    AwayTeamGoals = [int(x) for x in awayTeamLine]

x=[]
for i in range(1,len(HomeTeamGoals)+1):
    x.append(i)

fig2 = plt.figure("Second",figsize=(8,8))


ax1 = fig2.add_subplot(1,1,1)

ax1.plot(x,HomeTeamGoals,color =(1,0,.5), linestyle="--", linewidth=1, label = "HTG")

ax1.set_xlim(0,145)
ax1.set_ylim(0,7)
ax1.set_title("Home Team Goals over the season")
ax1.set_xlabel("Game number", labelpad=1)
ax1.set_ylabel("Home Team Goals")
ax1.legend(loc = "best") # upper, lower, center, left, right, best
#ax1.text(x = 40, y = 4, s= "text Text")
ax1.text(40, 4, s= "text Text", 
         horizontalalignment ="center", 
         verticalalignment = "center", 
         rotation = 60,
         style = "italic",
         weight = 1000) # 0 - 1000 , bold
 # horizontalalignment ="center"/"left"/"right" , verticalalignment = "center"/"top"/"bottom"/"left"/"right"

plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use("ggplot")

fig2 = plt.figure("Second",figsize=(8,8))


ax1 = fig2.add_subplot(1,1,1)

ax1.plot(x,HomeTeamGoals,color =(1,0,.5), linestyle="--", linewidth=1, label = "HTG")

ax1.set_xlim(0,145)
ax1.set_ylim(0,7)
ax1.set_title("Home Team Goals over the season")
ax1.set_xlabel("Game number", labelpad=1)
ax1.set_ylabel("Home Team Goals")
ax1.legend(loc = "best") # upper, lower, center, left, right, best
ax1.text(40, 4, s= "text Text",
         horizontalalignment ="center", 
         verticalalignment = "center", 
         rotation = 60,
         style = "italic",
         weight = "bold") # 0 - 1000 , bold
plt.savefig("Images/text.png",orientation="potrait", dpi = 500)
plt.show()

# %% [markdown]
# # Histogram

# %%
with open("Data/Goals.txt","r") as goalData:
    homeTeamLine = goalData.readline()
    homeTeamLine = homeTeamLine.strip(" \n")
    homeTeamLine = homeTeamLine.split(" ")

    HomeTeamGoals = [int(x) for x in homeTeamLine]
    awayTeamLine = goalData.readline()
    awayTeamLine = awayTeamLine.strip(" \n")
    awayTeamLine = awayTeamLine.split(" ")

    AwayTeamGoals = [int(x) for x in awayTeamLine]

x=[]
for i in range(1,len(HomeTeamGoals)+1):
    x.append(i)

# %%
fig2 = plt.figure("Second",figsize = (6,6))
ax1 = fig2.add_subplot(1,1,1)

ax1.hist(x = (HomeTeamGoals, AwayTeamGoals), 
         bins = 7, #int / sequence 
         align = "mid", # left, mid, right
         #range = (1,3), # (min,max)
         color = ("red","blue"),
         cumulative= False # True, False
)

plt.show()

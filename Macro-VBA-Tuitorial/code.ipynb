# %%
import pandas as pd
import psycopg2
import numpy as np

# %%
def add_columns_containing_value(df, value):
    df['methods'] = None
    for i, row in df.iterrows():
        columns = row[row == value].index.tolist()
        columns_str = ','.join(columns)
        if columns:
            df.at[i, 'methods'] = columns_str
        else:
            df = df.drop(i)
    return df

# %%
# tmp_input_file = "Developability_Request-date.xlsm"

file_path = 'dev_sheet-somedate.xlsx'

# %%
db_host = '127.0.0.1'
db_port = '5432'
db_username = 'postgres'
db_password = 'password'
db_name = 'leap'

# Connect to PostgreSQL database
connection = psycopg2.connect(
    host=db_host,
    port=db_port,
    user=db_username,
    password=db_password,
    dbname=db_name
)

# %%
def load_devsheet(file_path):
    dev_sheet = pd.read_excel(file_path, "Dev. Sheet")
    dev_sheet.columns = dev_sheet.columns.str.strip()
    dev_sheet.rename(columns={
            'Sample Alias': 'sample_alias',
            'Measurement Prot. Conc. Date': 'measurement_prot_conc_date',
            'Measurement Prot. Conc. Contact': 'measurement_prot_conc_contact',
            'Startdatum Dialyse': 'startdatum_dialyse',
            'Proben Nr.': 'proben_nr',
            'Batch': 'batch',
            'Temperature': 'temperature',
            'Timepoint': 'timepoint',
            'Nanodrop [mg/ml]': 'nanodrop_mg_ml',
            'Buffer formulation': 'buffer_formulation',
            'Analysis Type': 'analysis_type',
            'nano-DSF': 'nanoDSF',
            'Study Code': 'study_code',
            'Lab': 'department',
            'PPB': 'ppb',
            'TPP': 'tpp',
            'APP': 'app',
            'Sanofi Project ID': 'internal_project_id',
            'TPP Name': 'tpp_name',
            'pI': 'isoelectric_point',
            'Format': 'format',
            'MW [kDa]': 'mw_kda',
            'Milestone': 'milestone',
            'PDS Liste': 'pds',
            'PAS Liste': 'pds',
            'Project ID': 'project_id',
            'Ext. Koeffizent': 'ext_cof',
            'Storage Temp [°C]': 'storage_temp',
            'Storage at -80 °C': 'storage_at_80'
        }, inplace=True)
    dev_sheet2 = add_columns_containing_value(dev_sheet, 'x')
    required_col = dev_sheet2[['milestone', 'pds', 'study_code', 'department', 'ppb', 'tpp',
       'app', 'project_id', 'internal_project_id', 'tpp_name', 'sample_alias',
       'measurement_prot_conc_date', 'measurement_prot_conc_contact',
       'startdatum_dialyse', 'proben_nr', 'batch', 'pH', 'temperature',
       'timepoint', 'nanodrop_mg_ml', 'buffer_formulation', 'analysis_type',
       'storage_temp', 'storage_at_80', 'ext_cof', 'isoelectric_point',
       'format', 'mw_kda', 'methods']].copy()
    columns_to_str = ['measurement_prot_conc_date', 'measurement_prot_conc_contact', 'batch', 'methods']
    required_col[columns_to_str] = required_col[columns_to_str].astype(str)
    startdatum_dialyse_na_df = required_col[required_col['startdatum_dialyse'].isna()]
    startdatum_dialyse_df = required_col.dropna(subset=['startdatum_dialyse'])
    return required_col, startdatum_dialyse_na_df, startdatum_dialyse_df

# %%
# dev_sheet.columns

# %%
# dev_sheet.columns

# %%
# dev_sheet2.columns

# %%
# 'pds','department','batch','ppb','tpp','app','internal_project_id','tpp_name','isoelectric_point','format','mw_kda','sample_alias','measurement_prot_conc_date','measurement_prot_conc_contact','startdatum_dialyse','proben_nr','pH','temperature','timepoint','nanodrop_mg_ml','buffer_formulation','analysis_type','RT','study_code','milestone','project_id','ext_cof','storage_temp','methods','storage_at_80'

# %%
required_col, startdatum_dialyse_na_df, startdatum_dialyse_df = load_devsheet(file_path)

# %%
required_col.shape[0]
# Out:
# 25

# %%
startdatum_dialyse_na_df.shape[0]
# Out:
# 4

# %%
startdatum_dialyse_df.shape[0]
# Out:
# 21

# %% [markdown]
# # Delete editted

# %%
query_existing_records = """SELECT id, sample_alias, measurement_prot_conc_contact, temperature, pH, batch, tpp_name, methods, startdatum_dialyse
                            FROM order_list_clap_missing"""
old_dev_miss_record = pd.read_sql(query_existing_records, connection)

# Ensure the specified columns are converted to string

old_dev_miss_record.columns
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_25736\3746391360.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   old_dev_miss_record = pd.read_sql(query_existing_records, connection)
# Index(['id', 'sample_alias', 'measurement_prot_conc_contact', 'temperature',
#        'ph', 'batch', 'tpp_name', 'methods', 'startdatum_dialyse'],
#       dtype='object')

# %%
columns_to_str = ['sample_alias','measurement_prot_conc_contact', 'batch', 'methods']
old_dev_miss_record[columns_to_str] = old_dev_miss_record[columns_to_str].astype(str)
records_to_remove = startdatum_dialyse_df.merge(old_dev_miss_record[['sample_alias', 'methods']], on=['sample_alias', 'methods'])

# %%
print("Records to remove:", records_to_remove.shape[0])
# Out:
# Records to remove: 2

# %%
records_to_remove
# Out:
#         milestone       pds study_code      department        ppb         tpp  \
# 0  Custom Package  PDS-3878    NTD1196  Frankfurt (DE)  PPB-62611   TPP-52259
# 1  Custom Package  PDS-3878    NTD1196  Frankfurt (DE)  PPB-97344  TPP-125766
#
#          app project_id internal_project_id  \
# 0  APP-34697    PRJ-246             RC00874
# 1  APP-49740    PRJ-246             RC00874
#
#                                       tpp_name  ... nanodrop_mg_ml  \
# 0   anti-ERBB2-(Trastuzumab)-huIgG1(LALA-GASS)  ...            NaN
# 1  anti-ERBB2-(Trastuzumab)-huIgG1(LALA) P329A  ...            NaN
#
#   buffer_formulation   analysis_type storage_temp  storage_at_80 ext_cof  \
# 0   10 mM Acetat pH5  Developability        -80°C            NaN    1.49
# 1   10 mM Acetat pH5  Developability        -80°C            NaN    1.49
#
#   isoelectric_point  format    mw_kda                    methods
# 0               9.1     IgG  144.8662  MS-IM,HIC,SEC,nanoDSF,DLS
# 1               9.1     IgG  144.8824  MS-IM,HIC,SEC,nanoDSF,DLS
#
# [2 rows x 29 columns]

# %%
old_dev_miss_record
# Out:
#    id               sample_alias measurement_prot_conc_contact temperature  \
# 0   7   1_FF-22-1065-6_pH5_T0_40                     Tina, Isa        40.0
# 1   8   3_FF-23-1629-2_pH5_T0_40                     Tina, Isa        40.0
# 2   9   5_FF-23-1630-2_pH5_T0_40                     Tina, Isa        40.0
# 3  10  6_FF-23-1630-2_pH5_T21_40                     Tina, Isa        40.0
# 4  11  2_FF-22-1065-6_pH5_T21_40                     Tina, Isa        40.0
# 5  12  4_FF-23-1629-2_pH5_T21_40                     Tina, Isa        40.0
#
#     ph         batch                                     tpp_name  \
# 0  pH5  FF-22-1065-6   anti-ERBB2-(Trastuzumab)-huIgG1(LALA-GASS)
# 1  pH5  FF-23-1629-2  anti-ERBB2-(Trastuzumab)-huIgG1(LALA) P329A
# 2  pH5  FF-23-1630-2    anti-ERBB2-(Trastuzumab)-huIgG1(LALA-GSS)
# 3  pH5  FF-23-1630-2    anti-ERBB2-(Trastuzumab)-huIgG1(LALA-GSS)
# 4  pH5  FF-22-1065-6   anti-ERBB2-(Trastuzumab)-huIgG1(LALA-GASS)
# 5  pH5  FF-23-1629-2  anti-ERBB2-(Trastuzumab)-huIgG1(LALA) P329A
#
#                      methods startdatum_dialyse
# 0  MS-IM,HIC,SEC,nanoDSF,DLS               None
# 1  MS-IM,HIC,SEC,nanoDSF,DLS               None
# 2  MS-IM,HIC,SEC,nanoDSF,DLS               None
# 3  MS-IM,HIC,SEC,nanoDSF,DLS               None
# 4  MS-IM,HIC,SEC,nanoDSF,DLS               None
# 5  MS-IM,HIC,SEC,nanoDSF,DLS               None

# %%
startdatum_dialyse_df
# Out:
#          milestone       pds        study_code      department        ppb  \
# 0          post-M1  PDS-3636           L2C0161  Frankfurt (DE)  PPB-96531
# 1          post-M1  PDS-3636           L2C0161  Frankfurt (DE)  PPB-96537
# 2          post-M1  PDS-3636           L2C0161  Frankfurt (DE)  PPB-96537
# 3          post-M1  PDS-3636           L2C0161  Frankfurt (DE)  PPB-96530
# 4          post-M1  PDS-3636           L2C0161  Frankfurt (DE)  PPB-96530
# 5          post-M1  PDS-3636           L2C0161  Frankfurt (DE)  PPB-96536
# 6          post-M1  PDS-3636           L2C0161  Frankfurt (DE)  PPB-96536
# 7          post-M1  PDS-3636           L2C0161  Frankfurt (DE)  PPB-96529
# 8          post-M1  PDS-3636           L2C0161  Frankfurt (DE)  PPB-96529
# 9          post-M1  PDS-3636           L2C0161  Frankfurt (DE)  PPB-96535
# 10         post-M1  PDS-3636           L2C0161  Frankfurt (DE)  PPB-96535
# 11         post-M1  PDS-3651  L2C0161, LC81286  Frankfurt (DE)  PPB-96683
# 12         post-M1  PDS-3651  L2C0161, LC81286  Frankfurt (DE)  PPB-96683
# 13         post-M1  PDS-3651  L2C0161, LC81286  Frankfurt (DE)  PPB-96684
# 14         post-M1  PDS-3651  L2C0161, LC81286  Frankfurt (DE)  PPB-96684
# 15         post-M1  PDS-3674  L2C0161, LC81286  Frankfurt (DE)  PPB-96685
# 16         post-M1  PDS-3674  L2C0161, LC81286  Frankfurt (DE)  PPB-96685
# 17         post-M1  PDS-3674  L2C0161, LC81286  Frankfurt (DE)  PPB-96686
# 18         post-M1  PDS-3674  L2C0161, LC81286  Frankfurt (DE)  PPB-96686
# 20  Custom Package  PDS-3878           NTD1196  Frankfurt (DE)  PPB-62611
# 22  Custom Package  PDS-3878           NTD1196  Frankfurt (DE)  PPB-97344
#
#            tpp        app project_id internal_project_id  \
# 0   TPP-125186  APP-49848    PRJ-416             LC81286
# 1   TPP-125186  APP-49848    PRJ-416             LC81286
# 2   TPP-125186  APP-49848    PRJ-416             LC81286
# 3   TPP-125190  APP-49844    PRJ-416             LC81286
# 4   TPP-125190  APP-49844    PRJ-416             LC81286
# 5   TPP-125190  APP-49844    PRJ-416             LC81286
# 6   TPP-125190  APP-49844    PRJ-416             LC81286
# 7   TPP-125450  APP-49563    PRJ-416             LC81286
# 8   TPP-125450  APP-49563    PRJ-416             LC81286
# 9   TPP-125450  APP-49563    PRJ-416             LC81286
# 10  TPP-125450  APP-49563    PRJ-416             LC81286
# 11  TPP-136626  APP-57472    PRJ-416             LC81286
# 12  TPP-136626  APP-57472    PRJ-416             LC81286
# 13  TPP-136626  APP-57472    PRJ-416             LC81286
# 14  TPP-136626  APP-57472    PRJ-416             LC81286
# 15  TPP-136845  APP-57475    PRJ-416             LC81286
# 16  TPP-136845  APP-57475    PRJ-416             LC81286
# 17  TPP-136845  APP-57475    PRJ-416             LC81286
# 18  TPP-136845  APP-57475    PRJ-416             LC81286
# 20   TPP-52259  APP-34697    PRJ-246             RC00874
# 22  TPP-125766  APP-49740    PRJ-246             RC00874
#
#                                              tpp_name  ... nanodrop_mg_ml  \
# 0   aIl23-(119A03_1641-E1D-VHH)-Fc-LALA-K-al23-(08...  ...          1.047
# 1   aIl23-(119A03_1641-E1D-VHH)-Fc-LALA-K-al23-(08...  ...          1.061
# 2   aIl23-(119A03_1641-E1D-VHH)-Fc-LALA-K-al23-(08...  ...          1.084
# 3   aIl23-(119A03_1641-E1D-VHH)-Fc-LALA-K-al23-(08...  ...          1.056
# 4   aIl23-(119A03_1641-E1D-VHH)-Fc-LALA-K-al23-(08...  ...          0.755
# 5   aIl23-(119A03_1641-E1D-VHH)-Fc-LALA-K-al23-(08...  ...          1.106
# 6   aIl23-(119A03_1641-E1D-VHH)-Fc-LALA-K-al23-(08...  ...          1.132
# 7   (aOSM(04G03_1410-E1D)<9GS>aOSM(06B03_1447) x a...  ...          1.032
# 8   (aOSM(04G03_1410-E1D)<9GS>aOSM(06B03_1447) x a...  ...          1.029
# 9   (aOSM(04G03_1410-E1D)<9GS>aOSM(06B03_1447) x a...  ...          1.019
# 10  (aOSM(04G03_1410-E1D)<9GS>aOSM(06B03_1447) x a...  ...          1.025
# 11  (aIL23p19-(H626_5378)-FcK-aOSM-(52B01_A0417018...  ...          1.013
# 12  (aIL23p19-(H626_5378)-FcK-aOSM-(52B01_A0417018...  ...            NaN
# 13  (aIL23p19-(H626_5378)-FcK-aOSM-(52B01_A0417018...  ...          0.888
# 14  (aIL23p19-(H626_5378)-FcK-aOSM-(52B01_A0417018...  ...            NaN
# 15  (anti-OSM-(07G02_A041702304)-E1D-VHH) x anti-I...  ...          0.987
# 16  (anti-OSM-(07G02_A041702304)-E1D-VHH) x anti-I...  ...            NaN
# 17  (anti-OSM-(07G02_A041702304)-E1D-VHH) x anti-I...  ...          0.997
# 18  (anti-OSM-(07G02_A041702304)-E1D-VHH) x anti-I...  ...            NaN
# 20         anti-ERBB2-(Trastuzumab)-huIgG1(LALA-GASS)  ...            NaN
# 22        anti-ERBB2-(Trastuzumab)-huIgG1(LALA) P329A  ...            NaN
#
#     buffer_formulation   analysis_type storage_temp  storage_at_80 ext_cof  \
# 0     10 mM Acetat pH5  Developability        -80°C             E9    1.51
# 1   10 mM Phosphat pH8  Developability        -80°C             E9    1.51
# 2   10 mM Phosphat pH8  Developability        -80°C             E9    1.51
# 3     10 mM Acetat pH5  Developability        -80°C             E9    1.54
# 4     10 mM Acetat pH5  Developability        -80°C             E9    1.54
# 5   10 mM Phosphat pH8  Developability        -80°C             E9    1.54
# 6   10 mM Phosphat pH8  Developability        -80°C             E9    1.54
# 7     10 mM Acetat pH5  Developability        -80°C             E9    1.59
# 8     10 mM Acetat pH5  Developability        -80°C             E9    1.59
# 9   10 mM Phosphat pH8  Developability        -80°C             E9    1.59
# 10  10 mM Phosphat pH8  Developability        -80°C             E9    1.59
# 11    10 mM Acetat pH5  Developability        -80°C             E9    1.56
# 12    10 mM Acetat pH5  Developability        -80°C             E9    1.56
# 13  10 mM Phosphat pH8  Developability        -80°C             E9    1.56
# 14  10 mM Phosphat pH8  Developability        -80°C             E9    1.56
# 15    10 mM Acetat pH5  Developability        -80°C             E9    1.51
# 16    10 mM Acetat pH5  Developability        -80°C             E9    1.51
# 17  10 mM Phosphat pH8  Developability        -80°C             E9    1.51
# 18  10 mM Phosphat pH8  Developability        -80°C             E9    1.51
# 20    10 mM Acetat pH5  Developability        -80°C            NaN    1.49
# 22    10 mM Acetat pH5  Developability        -80°C            NaN    1.49
#
#    isoelectric_point                      format    mw_kda  \
# 0                9.2    3-Chain Generic Antibody  127.5690
# 1                9.2    3-Chain Generic Antibody  127.5690
# 2                9.2    3-Chain Generic Antibody  127.5690
# 3                9.2    3-Chain Generic Antibody  128.0946
# 4                9.2    3-Chain Generic Antibody  128.0946
# 5                9.2    3-Chain Generic Antibody  128.0946
# 6                9.2    3-Chain Generic Antibody  128.0946
# 7                8.2    3-Chain Generic Antibody  126.2843
# 8                8.2    3-Chain Generic Antibody  126.2843
# 9                8.2    3-Chain Generic Antibody  126.2843
# 10               8.2    3-Chain Generic Antibody  126.2843
# 11               7.7  (Fv-Fab x Fv-Fab)-Fc_VH(2)  159.2833
# 12               7.7  (Fv-Fab x Fv-Fab)-Fc_VH(2)  159.2833
# 13               7.7  (Fv-Fab x Fv-Fab)-Fc_VH(2)  159.2833
# 14               7.7  (Fv-Fab x Fv-Fab)-Fc_VH(2)  159.2833
# 15               8.5           (Fv-Fab x VHH)-Fc  112.1509
# 16               8.5           (Fv-Fab x VHH)-Fc  112.1509
# 17               8.5           (Fv-Fab x VHH)-Fc  112.1509
# 18               8.5           (Fv-Fab x VHH)-Fc  112.1509
# 20               9.1                         IgG  144.8662
# 22               9.1                         IgG  144.8824
#
#                                               methods
# 0   CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 1   CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 2   CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 3   CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 4   CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 5   CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 6   CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 7   CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 8   CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 9   CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 10  CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 11  CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 12  CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 13  CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 14  CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 15  CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 16  CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 17  CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 18  CE-SDS,HIC,SEC,Biacore - Active Concentration,...
# 20                          MS-IM,HIC,SEC,nanoDSF,DLS
# 22                          MS-IM,HIC,SEC,nanoDSF,DLS
#
# [21 rows x 29 columns]

# %%
# print(startdatum_dialyse_df[['sample_alias', 'methods', 'startdatum_dialyse']].dtypes)
# print(old_dev_miss_record[['sample_alias', 'methods', 'startdatum_dialyse']].dtypes)

# %%
# startdatum_dialyse_df['sample_alias'] = startdatum_dialyse_df['sample_alias'].str.lower()
# startdatum_dialyse_df['methods'] = startdatum_dialyse_df['methods'].str.lower()
# startdatum_dialyse_df['startdatum_dialyse'] = startdatum_dialyse_df['startdatum_dialyse'].str.lower()

# old_dev_miss_record['sample_alias'] = old_dev_miss_record['sample_alias'].str.lower()
# old_dev_miss_record['methods'] = old_dev_miss_record['methods'].str.lower()
# old_dev_miss_record['startdatum_dialyse'] = old_dev_miss_record['startdatum_dialyse'].str.lower()

# %%
# startdatum_dialyse_df[['sample_alias', 'methods', 'startdatum_dialyse']]

# %%
# old_dev_miss_record[['sample_alias', 'methods', 'startdatum_dialyse']]

# %%
# print(startdatum_dialyse_df[['sample_alias', 'methods', 'startdatum_dialyse']].isna().sum())
# print(old_dev_miss_record[['sample_alias', 'methods', 'startdatum_dialyse']].isna().sum())

# %%
# common_rows

# %%
# old_dev_miss_record.columns

# %%
# s1 = pd.merge(startdatum_dialyse_df,old_dev_miss_record, how = 'inner',indicator=False)

# %%
# s1

# %%
# merged = startdatum_dialyse_df.merge(old_dev_miss_record, how='left', on=['sample_alias', 'measurement_prot_conc_contact', 'temperature',  'batch', 'tpp_name', 'methods', 'startdatum_dialyse'], indicator=True)
# # New_Dev_miss_records = merged[merged['_merge'] == 'left_only'].drop(['_merge'], axis=1)

# %%
# New_Dev_miss_records = merged[merged['_merge'] == 'left_only'].drop(['_merge'], axis=1)

# %%
# New_Dev_miss_records

# %%
# # Identify records to remove
# records_to_remove = old_dev_miss_record.merge(startdatum_dialyse_df, on=['sample_alias', 'measurement_prot_conc_contact', 'batch', 'methods','startdatum_dialyse'])
# print("Records to remove:", records_to_remove.shape[0])

# %%
# Delete records from database
if not records_to_remove.empty:
    cursor = connection.cursor()
    records_to_remove = records_to_remove.replace({np.nan: ''})
    for _, row in records_to_remove.iterrows():
        if row['measurement_prot_conc_date'] == 'NaT':
            row['measurement_prot_conc_date'] = None
        sql_delete = "DELETE FROM order_list_clap_missing WHERE sample_alias = %s AND measurement_prot_conc_contact = %s  AND batch = %s AND methods = %s"
        val_delete = (row['sample_alias'],  row['measurement_prot_conc_contact'],row['batch'], row['methods'])
        try:
            cursor.execute(sql_delete, val_delete)
            print(f"Query executed: {sql_delete} : {val_delete}")
        except Exception as e:
            print("Delete query error:", e)
    try:
        connection.commit()
    except Exception as e:
        print("Error committing delete transactions:", e)
# Out:
# Query executed: DELETE FROM order_list_clap_missing WHERE sample_alias = %s AND measurement_prot_conc_contact = %s  AND batch = %s AND methods = %s : ('2_FF-22-1065-6_pH5_T21_40', 'Tina, Isa', 'FF-22-1065-6', 'MS-IM,HIC,SEC,nanoDSF,DLS')
# Query executed: DELETE FROM order_list_clap_missing WHERE sample_alias = %s AND measurement_prot_conc_contact = %s  AND batch = %s AND methods = %s : ('4_FF-23-1629-2_pH5_T21_40', 'Tina, Isa', 'FF-23-1629-2', 'MS-IM,HIC,SEC,nanoDSF,DLS')

# %% [markdown]
# # Insert new

# %%
# Query existing records from the PostgreSQL database
try:
    query3 = """SELECT sample_alias, measurement_prot_conc_contact, temperature, pH, batch, tpp_name, methods
                FROM order_list_clap_missing"""
    old_dev_miss_record = pd.read_sql(query3, connection)
    columns_to_str = ['sample_alias', 'measurement_prot_conc_contact', 'temperature', 'ph', 'batch', 'tpp_name', 'methods']
    old_dev_miss_record[columns_to_str] = old_dev_miss_record[columns_to_str].astype(str)

    merged2 = startdatum_dialyse_na_df.merge(old_dev_miss_record, how='left', indicator=True)
    New_Dev_miss_records = merged2[merged2['_merge'] == 'left_only'].drop(['_merge'], axis=1)
    
    print("New Developability Record count: {}".format(New_Dev_miss_records.shape[0]))
except Exception as e:
    print("Error: ", e)
    New_Dev_miss_records = pd.DataFrame()
# Out:
# Error:  You are trying to merge on float64 and object columns for key 'temperature'. If you wish to proceed you should use pd.concat
# C:\Users\user\AppData\Local\Temp\ipykernel_25736\2603746170.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   old_dev_miss_record = pd.read_sql(query3, connection)

# %%
New_Dev_miss_records
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Update Developability info into PostgreSQL Table
if not New_Dev_miss_records.empty:
    New_Dev_filter_records = New_Dev_miss_records
else:
    print("New records not found in Developability sheet")
    New_Dev_filter_records = pd.DataFrame()
# Out:
# New records not found in Developability sheet

# %%
cur = connection.cursor()

if not New_Dev_filter_records.empty:
    New_Dev_filter_records = New_Dev_filter_records.replace({np.nan: ''})
    # df.replace({np.nan: '', None: ''}, inplace=True)
    for index, row in New_Dev_filter_records.iterrows():
        if row['measurement_prot_conc_date'] == 'nan':
            row['measurement_prot_conc_date'] = None
        if row['startdatum_dialyse'] == 'nan' or row['startdatum_dialyse'] == 'NaT':
            row['startdatum_dialyse'] = None

        sql2 = """INSERT INTO order_list_clap_missing 
                  (pds, department, batch, ppb, tpp, app, internal_project_id, tpp_name, isoelectric_point, format, mw_kda, 
                   sample_alias, measurement_prot_conc_date, measurement_prot_conc_contact, startdatum_dialyse, proben_nr, pH, 
                   temperature, timepoint, nanodrop_mg_ml, buffer_formulation, analysis_type, RT, study_code, milestone, 
                   project_id, ext_cof, storage_temp, methods) 
                  VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, 
                          # %s, %s, %s,%s)"""
        val2 = (row['pds'], row['department'], row['batch'], row['ppb'], row['tpp'], row['app'], row['internal_project_id'], 
                row['tpp_name'], row['isoelectric_point'], row['format'], row['mw_kda'], row['sample_alias'], 
                row['measurement_prot_conc_date'], row['measurement_prot_conc_contact'], row['startdatum_dialyse'], 
                row['proben_nr'], row['pH'], row['temperature'], row['timepoint'], row['nanodrop_mg_ml'], 
                row['buffer_formulation'], row['analysis_type'], "DEV", row['study_code'], row['milestone'], 
                row['project_id'], row['ext_cof'], row['storage_temp'], row['methods'])
        
        try:
            cur.execute(sql2, val2)
            print("New missing Developability records were added to the database")
        except Exception as e:
            print(e)

    try:
        connection.commit()
    except Exception as e:
        print("Error committing transaction: ", e)
